# %% [markdown]
# # Import Libraries and Inspect Data

# %%
# standard library imports
from ast import literal_eval
import itertools
# import time
# import re

# third-party imports
import numpy as np
import pandas as pd

# customisations
pd.options.display.max_columns = 100

# %%
raw_steamspy_data = pd.read_csv('../Data/steam_spy_data.csv')
raw_steamspy_data.head()
# Out:
#      appid                           name               developer  \
# 0   216938  Pieterw test app76 ( 216938 )                     NaN
# 1   660010                          test2                     NaN
# 2   660130                          test3                     NaN
# 3  1433210             Notebook Artillery  Austin Ivansmith Games
# 4  1433240                 Whiskey Island           Raymond Lewis
#
#                 publisher  score_rank  positive  negative  userscore  \
# 0                     NaN         NaN         0         0          0
# 1                     NaN         NaN         0         0          0
# 2                     NaN         NaN         0         0          0
# 3  Austin Ivansmith Games         NaN        10         0          0
# 4           Raymond Lewis         NaN         1         1          0
#
#         owners  average_forever  average_2weeks  median_forever  \
# 0  0 .. 20,000                0               0               0
# ...
